# %%
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
print(len(data))
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5242, 3083, 12, 6, 195, 2, 3134, 46, 59, 156]
# 17005207

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]

    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:  
    # (2,1) saves words adjacent to the word and (4,2) saves 2 words adjacent tom the word
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'as', 'term', 'of', 'originated']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.495296
# Nearest to would: hur, iquique, tycoon, handguard, knuckle, mihdhar, innes, interacting,
# Nearest to its: uplift, tiraspol, woke, sahara, lowell, triggers, belushi, rapes,
# Nearest to known: dominican, pirate, winchell, proclaims, microwaves, pataki, idiots, redness,
# Nearest to use: drowned, cubewanos, acrobatic, invertible, putnam, presbyterianism, fgc, saul,
# Nearest to no: dagobert, webs, discarding, syncretism, telecasts, minuet, respectful, unfavourably,
# Nearest to war: addis, ordovician, accomplishment, exchequer, hosted, medi, bec, unsolved,
# Nearest to five: hjalmar, dom, beside, pike, signifies, vigil, yacc, antisocial,
# Nearest to have: alarmed, endorsed, amram, rapid, skimmed, reflect, topological, abbeys,
# Nearest to i: cellar, vicious, shankar, atone, followers, arianism, autocephalous, northwards,
# Nearest to united: stamp, ein, citing, bering, lancastrian, daniels, monotonous, mam,
# Nearest to been: lupus, haldeman, alfonso, cordon, diasporas, dagda, hadassah, landscapes,
# Nearest to his: wigs, cpm, adaptations, boudica, goyen, beau, alchemical, hangul,
# Nearest to history: crews, hires, issues, franca, diluted, unsuspecting, accessible, geothermal,
# Nearest to into: overtook, exercising, laity, shell, deadlines, tum, dragons, bible,
# Nearest to state: joysticks, gauges, icftu, luxembourgish, fanfare, happier, hbo, mansions,
# Nearest to but: pretending, solvable, readership, cult, gunned, jacobins, conectiva, pickering,
# Average loss at step 2000: 4.351266
# Average loss at step 4000: 3.863590
# Average loss at step 6000: 3.786383
# Average loss at step 8000: 3.688536
# Average loss at step 10000: 3.615393
# Nearest to would: will, could, can, knuckle, iquique, tycoon, to, derivations,
# Nearest to its: the, their, his, tiraspol, irrational, filename, imaging, picture,
# Nearest to known: well, mackay, microwaves, winchell, dangerous, belligerent, assignment, pirate,
# Nearest to use: cubewanos, presbyterianism, drowned, unprotected, saul, organically, imprinted, ayatollah,
# Nearest to no: it, dagobert, errant, nsc, webs, futuristic, minuet, henri,
# Nearest to war: addis, exchequer, accomplishment, mara, resisted, mandate, duplicate, ordovician,
# Nearest to five: eight, three, six, four, seven, nine, zero, two,
# Nearest to have: be, had, has, are, reflect, were, emmanuel, alarmed,
# Nearest to i: cellar, camped, abitibi, he, shankar, autocephalous, strathclyde, hardline,
# Nearest to united: citing, ein, amidah, next, dukakis, bering, royal, polis,
# Nearest to been: lupus, was, actually, supervise, bopp, marion, be, mep,
# Nearest to his: their, her, s, the, its, alchemical, mediating, treeless,
# Nearest to history: crews, franca, satellite, part, hires, issues, confederate, layout,
# Nearest to into: overtook, tum, exercising, respiration, sala, commitment, diffuse, gunships,
# Nearest to state: luxembourgish, contention, gauges, joysticks, hbo, many, community, halide,
# Nearest to but: curd, discard, cult, mediated, sedatives, cannot, pretending, abaci,
# Average loss at step 12000: 3.608206
# Average loss at step 14000: 3.564296
# Average loss at step 16000: 3.409120
# Average loss at step 18000: 3.457950
# Average loss at step 20000: 3.538982
# Nearest to would: will, could, can, may, might, did, should, derivations,
# Nearest to its: their, his, the, irrational, tiraspol, picture, her, control,
# Nearest to known: such, used, dangerous, well, assignment, served, microwaves, mackay,
# Nearest to use: cubewanos, unprotected, drowned, presbyterianism, saul, imprinted, ayatollah, court,
# Nearest to no: a, any, it, dagobert, slash, minuet, futuristic, analogous,
# Nearest to war: addis, exchequer, mara, accomplishment, unionism, resisted, hotham, chk,
# Nearest to five: four, six, seven, eight, three, zero, two, nine,
# Nearest to have: had, has, be, were, are, osama, statisticians, jeremiah,
# Nearest to i: ii, strathclyde, exodus, panicked, tackles, hardline, suda, eo,
# Nearest to united: ein, next, dukakis, citing, royal, amidah, sarris, sacco,
# Nearest to been: be, actually, lupus, were, was, never, bopp, by,
# Nearest to his: their, her, its, enlil, the, slowly, this, cereal,
# Nearest to history: part, franca, issues, layout, satellite, sentient, monastic, crews,
# Nearest to into: from, tum, overtook, upon, by, respiration, through, exercising,
# Nearest to state: gauges, contention, luxembourgish, ocampo, community, halide, mods, joysticks,
# Nearest to but: which, although, and, making, that, is, however, though,
# Average loss at step 22000: 3.501954
# Average loss at step 24000: 3.492742
# Average loss at step 26000: 3.482821
# Average loss at step 28000: 3.481678
# Average loss at step 30000: 3.502972
# Nearest to would: will, could, can, may, should, might, must, shall,
# Nearest to its: their, his, the, our, her, colons, olde, s,
# Nearest to known: used, well, such, served, assignment, dangerous, described, regarded,
# Nearest to use: cubewanos, unprotected, drowned, josie, presbyterianism, exploitation, saul, rearing,
# Nearest to no: any, a, analogous, it, minuet, webs, expediency, dagobert,
# Nearest to war: addis, exchequer, mara, unionism, masterpieces, iit, hotham, detergents,
# Nearest to five: four, eight, seven, three, six, nine, zero, two,
# Nearest to have: had, has, were, are, be, having, jeremiah, osama,
# Nearest to i: ii, strathclyde, you, officeholders, gasolines, abitibi, exodus, bono,
# Nearest to united: royal, ein, next, dukakis, citing, sacco, amidah, modulator,
# Nearest to been: become, was, be, were, actually, lupus, never, by,
# Nearest to his: her, their, its, the, s, fermilab, enlil, my,
# Nearest to history: issues, layout, franca, sentient, monastic, list, satellite, mathura,
# Nearest to into: from, through, upon, tum, overtook, under, respiration, diffuse,
# Nearest to state: contention, gauges, ocampo, community, group, luxembourgish, environment, fibs,
# Nearest to but: however, although, and, though, that, which, when, could,
# Average loss at step 32000: 3.498971
# Average loss at step 34000: 3.499039
# Average loss at step 36000: 3.454166
# Average loss at step 38000: 3.306068
# Average loss at step 40000: 3.425944
# Nearest to would: will, could, can, may, should, might, must, did,
# Nearest to its: their, his, the, her, our, authorize, schubert, olde,
# Nearest to known: used, such, served, well, possible, described, sure, regarded,
# Nearest to use: cubewanos, way, unprotected, butane, try, josie, hanoi, pilsener,
# Nearest to no: any, a, analogous, minuet, routinely, combined, magnificat, anthropologists,
# Nearest to war: addis, exchequer, unionism, masterpieces, caloric, mara, hotham, ita,
# Nearest to five: seven, six, eight, four, three, zero, nine, two,
# Nearest to have: had, has, were, be, are, contain, having, toltec,
# Nearest to i: ii, you, we, they, he, bono, unilaterally, strathclyde,
# Nearest to united: ein, sacco, dukakis, citing, royal, shevardnadze, sarris, arab,
# Nearest to been: become, was, be, never, were, actually, lupus, had,
# Nearest to his: their, her, its, s, the, enlil, millard, my,
# Nearest to history: layout, wendy, part, crews, science, buck, list, monastic,
# Nearest to into: through, from, upon, tum, cartographic, overtook, respiration, dermal,
# Nearest to state: gauges, renovation, contention, ocampo, environment, immunotherapy, vez, universit,
# Nearest to but: however, though, although, which, and, preservatives, it, when,
# Average loss at step 42000: 3.430108
# Average loss at step 44000: 3.455821
# Average loss at step 46000: 3.446466
# Average loss at step 48000: 3.357607
# Average loss at step 50000: 3.383089
# Nearest to would: will, could, can, may, should, might, must, cannot,
# Nearest to its: their, his, the, our, her, olde, schubert, irrational,
# Nearest to known: used, served, such, well, possible, regarded, described, seen,
# Nearest to use: way, moog, butane, exploitation, admixture, unprotected, hanoi, illiterate,
# Nearest to no: any, analogous, kandinsky, a, webs, combined, impossible, magnificat,
# Nearest to war: addis, masterpieces, unionism, exchequer, thirty, mara, ishmael, lunatics,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to have: had, has, were, be, are, having, toltec, who,
# Nearest to i: ii, you, we, gediminas, yardage, unilaterally, he, democr,
# Nearest to united: ein, sacco, next, hindrance, dukakis, sarris, shevardnadze, interbreed,
# Nearest to been: become, be, was, were, never, previously, lupus, had,
# Nearest to his: her, their, its, my, your, s, the, enlil,
# Nearest to history: substantiate, franca, science, crews, deontological, list, club, layout,
# Nearest to into: through, from, upon, tum, around, magnetism, diffuse, overtook,
# Nearest to state: gauges, environment, renovation, ocampo, group, yunnan, vez, christiaan,
# Nearest to but: however, though, although, when, and, since, while, yet,
# Average loss at step 52000: 3.436323
# Average loss at step 54000: 3.425782
# Average loss at step 56000: 3.437911
# Average loss at step 58000: 3.395034
# Average loss at step 60000: 3.395907
# Nearest to would: could, will, can, may, might, should, must, cannot,
# Nearest to its: their, his, the, her, our, olde, albeit, filename,
# Nearest to known: used, such, served, regarded, possible, well, described, referred,
# Nearest to use: moog, hanoi, cause, cubewanos, layoffs, butane, hydrazine, experiencing,
# Nearest to no: any, combined, christianum, realised, analogous, magnificat, a, citt,
# Nearest to war: addis, masterpieces, exchequer, unionism, bambara, lunatics, ita, mara,
# Nearest to five: six, four, seven, three, eight, nine, zero, two,
# Nearest to have: has, had, are, were, include, having, be, require,
# Nearest to i: ii, you, we, g, unilaterally, he, barrymore, they,
# Nearest to united: sacco, ein, hindrance, dukakis, shevardnadze, royal, sarris, minimizing,
# Nearest to been: become, be, was, were, had, never, come, previously,
# Nearest to his: her, their, its, my, your, the, enlil, fermilab,
# Nearest to history: list, construction, introduction, deontological, science, procured, satellite, besiege,
# Nearest to into: through, from, around, tum, towards, upon, islamist, overtook,
# Nearest to state: renovation, environment, gauges, states, group, ocampo, government, regional,
# Nearest to but: however, although, and, though, since, yet, when, usually,
# Average loss at step 62000: 3.241051
# Average loss at step 64000: 3.255794
# Average loss at step 66000: 3.404927
# Average loss at step 68000: 3.394013
# Average loss at step 70000: 3.357631
# Nearest to would: could, will, can, may, might, should, must, cannot,
# Nearest to its: their, his, the, her, albeit, our, shaku, authorize,
# Nearest to known: used, such, regarded, served, seen, well, possible, described,
# Nearest to use: moog, cause, hanoi, exploitation, adversity, ternary, way, excommunicated,
# Nearest to no: any, combined, analogous, christianum, there, little, magnificat, somewhat,
# Nearest to war: addis, masterpieces, exchequer, unionism, heritage, rebellion, guardian, lunatics,
# Nearest to five: six, four, seven, three, eight, zero, nine, two,
# Nearest to have: had, has, were, are, having, contain, include, be,
# Nearest to i: ii, we, you, g, unilaterally, musicologists, barrymore, perlman,
# Nearest to united: sacco, ein, shevardnadze, dukakis, goodness, federal, shuffling, modulator,
# Nearest to been: become, be, was, were, previously, already, discoid, had,
# Nearest to his: her, their, its, my, your, our, schubert, him,
# Nearest to history: list, construction, yacc, introduction, theosophical, braddock, goering, maoism,
# Nearest to into: through, from, around, tum, towards, respiration, within, cartographic,
# Nearest to state: government, states, gauges, unbearable, contention, ansgar, ocampo, city,
# Nearest to but: however, although, and, though, which, that, preservatives, when,
# Average loss at step 72000: 3.377572
# Average loss at step 74000: 3.351712
# Average loss at step 76000: 3.311675
# Average loss at step 78000: 3.353995
# Average loss at step 80000: 3.378265
# Nearest to would: will, could, can, might, may, should, must, cannot,
# Nearest to its: their, his, her, our, the, schubert, albeit, brooks,
# Nearest to known: used, regarded, such, written, possible, defined, served, referred,
# Nearest to use: moog, exploitation, form, way, excommunicated, adopt, heretics, amount,
# Nearest to no: any, little, combined, christianum, realised, dolly, kandinsky, salah,
# Nearest to war: addis, masterpieces, mara, heritage, exchequer, filmi, rebellion, future,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to have: had, has, are, be, were, contain, having, tracy,
# Nearest to i: ii, we, you, g, t, unilaterally, trench, they,
# Nearest to united: federal, sacco, shevardnadze, goodness, muslim, shuffling, lancastrian, ein,
# Nearest to been: become, be, was, were, never, previously, come, recently,
# Nearest to his: her, their, my, its, your, our, the, welwyn,
# Nearest to history: list, besiege, construction, yacc, deontological, ministry, sentient, locomotive,
# Nearest to into: through, from, tum, around, towards, within, upon, respiration,
# Nearest to state: states, city, government, ansgar, ocampo, remittances, irregularity, tort,
# Nearest to but: however, although, while, though, and, yet, than, acrimonious,
# Average loss at step 82000: 3.401516
# Average loss at step 84000: 3.409510
# Average loss at step 86000: 3.390615
# Average loss at step 88000: 3.351322
# Average loss at step 90000: 3.364808
# Nearest to would: could, will, might, can, may, should, must, did,
# Nearest to its: their, his, her, our, the, schubert, your, some,
# Nearest to known: used, regarded, such, possible, described, served, seen, called,
# Nearest to use: moog, excommunicated, usage, presidium, proceeding, unprotected, adopt, need,
# Nearest to no: any, little, impossible, synergies, another, somewhat, jass, analogous,
# Nearest to war: addis, masterpieces, future, exchequer, mara, during, filmi, rebellion,
# Nearest to five: seven, eight, four, six, three, nine, zero, two,
# Nearest to have: had, has, were, be, are, having, include, contain,
# Nearest to i: g, we, you, ii, t, unilaterally, lambar, v,
# Nearest to united: federal, sacco, muslim, navy, shevardnadze, dukakis, goodness, shuffling,
# Nearest to been: become, be, was, were, already, previously, never, experienced,
# Nearest to his: her, their, its, my, your, our, the, enlil,
# Nearest to history: list, yacc, besiege, construction, ghostbusters, comedy, book, fiasco,
# Nearest to into: through, from, tum, around, towards, within, overtook, upon,
# Nearest to state: city, states, government, ansgar, fibs, superiors, tort, national,
# Nearest to but: however, although, and, though, until, while, yet, that,
# Average loss at step 92000: 3.391586
# Average loss at step 94000: 3.253932
# Average loss at step 96000: 3.357320
# Average loss at step 98000: 3.240456
# Average loss at step 100000: 3.357545
# Nearest to would: will, could, can, might, should, may, must, cannot,
# Nearest to its: their, his, our, the, her, your, schubert, seaman,
# Nearest to known: used, such, possible, regarded, served, described, referred, written,
# Nearest to use: moog, excommunicated, form, presidium, amount, usage, sense, klamath,
# Nearest to no: any, little, another, realised, christianum, analogous, impossible, dolly,
# Nearest to war: addis, masterpieces, unionism, rebellion, elitism, future, ishmael, mara,
# Nearest to five: four, seven, six, eight, three, zero, nine, two,
# Nearest to have: had, has, were, contain, having, be, include, are,
# Nearest to i: we, you, ii, g, they, v, t, bono,
# Nearest to united: federal, sacco, shevardnadze, muslim, sammy, teutonic, shuffling, confederate,
# Nearest to been: become, be, was, already, recently, were, previously, never,
# Nearest to his: her, their, its, my, your, the, our, s,
# Nearest to history: list, science, besiege, yacc, locomotive, book, introduction, construction,
# Nearest to into: through, from, within, upon, towards, tum, onto, around,
# Nearest to state: city, states, government, factbook, ansgar, zolt, irregularity, interludes,
# Nearest to but: however, although, and, though, while, preservatives, where, which,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
